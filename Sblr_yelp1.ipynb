# %%
import tensorflow_datasets as tfds
import pandas as pd

# Load the Yelp Polarity dataset
(train_data, test_data), info = tfds.load('yelp_polarity_reviews', split=['train', 'test'], with_info=True, as_supervised=True)

# Function to extract text and labels
def extract_data(dataset):
    texts = []
    labels = []
    for text, label in tfds.as_numpy(dataset):
        texts.append(text.decode('utf-8'))
        labels.append(int(label))
    return texts, labels

# Extract training and test data
train_texts, train_labels = extract_data(train_data)
test_texts, test_labels = extract_data(test_data)

# Create a dataframe for both train and test data
train_df = pd.DataFrame({
    'text': train_texts,
    'label': train_labels
})

test_df = pd.DataFrame({
    'text': test_texts,
    'label': test_labels
})

# Update file paths to save in the current directory
train_csv_path = 'yelp_train_data.csv'
test_csv_path = 'yelp_test_data.csv'

# Save the dataframes to CSV
train_df.to_csv(train_csv_path, index=False)
test_df.to_csv(test_csv_path, index=False)

print("Train CSV saved to:", train_csv_path)
print("Test CSV saved to:", test_csv_path)
# Out:
# Downloading and preparing dataset 158.67 MiB (download: 158.67 MiB, generated: 435.14 MiB, total: 593.80 MiB) to /root/tensorflow_datasets/yelp_polarity_reviews/0.2.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/560000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/yelp_polarity_reviews/incomplete.YIGVKP_0.2.0/yelp_polarity_reviews-train.…
# Generating test examples...:   0%|          | 0/38000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/yelp_polarity_reviews/incomplete.YIGVKP_0.2.0/yelp_polarity_reviews-test.t…
# Dataset yelp_polarity_reviews downloaded and prepared to /root/tensorflow_datasets/yelp_polarity_reviews/0.2.0. Subsequent calls will reuse this data.
# Train CSV saved to: yelp_train_data.csv
# Test CSV saved to: yelp_test_data.csv

# %%
(train_data, test_data), info = tfds.load(
    'yelp_polarity_reviews',
    split=['train', 'test'],
    with_info=True,
    as_supervised=True,
    data_dir='/your/custom/path'
)
# Out:
# Downloading and preparing dataset 158.67 MiB (download: 158.67 MiB, generated: 435.14 MiB, total: 593.80 MiB) to /your/custom/path/yelp_polarity_reviews/0.2.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/560000 [00:00<?, ? examples/s]
# Shuffling /your/custom/path/yelp_polarity_reviews/incomplete.VYOU8R_0.2.0/yelp_polarity_reviews-train.tfrecord…
# Generating test examples...:   0%|          | 0/38000 [00:00<?, ? examples/s]
# Shuffling /your/custom/path/yelp_polarity_reviews/incomplete.VYOU8R_0.2.0/yelp_polarity_reviews-test.tfrecord*…
# Dataset yelp_polarity_reviews downloaded and prepared to /your/custom/path/yelp_polarity_reviews/0.2.0. Subsequent calls will reuse this data.

# %%
# Required Libraries
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.linear_model import BayesianRidge
from sklearn.metrics import (accuracy_score, precision_score, recall_score,
                             f1_score, roc_auc_score, log_loss, confusion_matrix)
from time import time
import numpy as np

# Load the Yelp Polarity Dataset
train_df = pd.read_csv('yelp_train_data.csv')
test_df = pd.read_csv('yelp_test_data.csv')

# Combine train and test data for vectorization (optional but helps in consistent vector space)
df = pd.concat([train_df, test_df], ignore_index=True)

# Text Preprocessing
vectorizer = CountVectorizer(stop_words='english')
X = vectorizer.fit_transform(df['text'])

# Dimensionality Reduction
svd = TruncatedSVD(n_components=500, random_state=42)
X_reduced = svd.fit_transform(X)

# Separate the training and test data after vectorization and dimensionality reduction
X_train, X_test = X_reduced[:len(train_df)], X_reduced[len(train_df):]
y_train, y_test = train_df['label'], test_df['label']

# Apply Sequential Bayesian Ridge Regression
model = BayesianRidge()

# Track training time
start_time = time()
batch_size = 1000
n_batches = int(np.ceil(X_train.shape[0] / batch_size))

for batch_num in range(n_batches):
    start_idx = batch_num * batch_size
    end_idx = min((batch_num + 1) * batch_size, X_train.shape[0])
    X_batch = X_train[start_idx:end_idx]
    y_batch = y_train[start_idx:end_idx]
    model.fit(X_batch, y_batch)
    print(f'Batch {batch_num + 1}/{n_batches} processed')

training_time = time() - start_time
print(f"\nTraining Time: {training_time:.2f} seconds")

# Predict on Test Data
y_pred_prob = model.predict(X_test)
y_pred_class = [1 if prob > 0.5 else 0 for prob in y_pred_prob]

# 1. Accuracy
accuracy = accuracy_score(y_test, y_pred_class) * 100
print(f'Accuracy: {accuracy:.2f}%')

# 2. Loss (Log-Loss)
loss = log_loss(y_test, y_pred_prob)
print(f"Log-Loss: {loss:.2f}")

# 3. Precision, Recall, and F1-Score
precision = precision_score(y_test, y_pred_class)
recall = recall_score(y_test, y_pred_class)
f1 = f1_score(y_test, y_pred_class)
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")

# 4. Uncertainty Estimation (Variance in predictions as proxy)
prediction_var = np.var(y_pred_prob)
print(f"Prediction Variance (proxy for uncertainty): {prediction_var:.4f}")

# 5. Training Time (Computational Efficiency)
print(f"Training Time: {training_time:.2f} seconds")

# 6. Overfitting / Generalization
train_pred_class = model.predict(X_train)
train_accuracy = accuracy_score(y_train, [1 if prob > 0.5 else 0 for prob in train_pred_class]) * 100
print(f"Training Accuracy: {train_accuracy:.2f}%")
print(f"Test Accuracy (for Generalization check): {accuracy:.2f}%")
print("Generalization Check: No significant drop indicates good generalization")

# 7. Model Calibration (AUC-ROC as proxy for calibration quality)
auc_roc = roc_auc_score(y_test, y_pred_prob)
print(f"AUC-ROC (Calibration Proxy): {auc_roc:.2f}")

# 8. Noise Sensitivity (Accuracy with noise percentage)
correct_predictions = np.sum(np.array(y_pred_class) == np.array(y_test))
accuracy_with_noise_percent = (correct_predictions / len(y_test)) * 100
print(f"Accuracy with Noise (Percentage of Correct Predictions): {accuracy_with_noise_percent:.2f}%")

# 9. Model Complexity (Simplicity of SBLR vs. complex BNN discussed in comments)
print("Model Complexity: SBLR is simpler than BNN, suited for smaller data with fewer parameters.")

# 10. AUC-ROC (Separate from calibration to measure discrimination capability)
print(f"AUC-ROC: {auc_roc:.2f}")

# 11. Confidence Intervals (not available in SBLR, would be for BNN)
# SBLR does not natively provide confidence intervals on predictions; approximated by variance

# 12. Scalability (Training Time as Proxy)
print(f"Scalability Check (Training Time for Large Datasets): {training_time:.2f} seconds")

# Summary Output
print("\n=== Model Evaluation Summary ===")
print(f"1. Accuracy: {accuracy:.2f}%")
print(f"2. Log-Loss: {loss:.2f}")
print(f"3. Precision: {precision:.2f}, Recall: {recall:.2f}, F1-Score: {f1:.2f}")
print(f"4. Uncertainty Estimation (Variance): {prediction_var:.4f}")
print(f"5. Training Time: {training_time:.2f} seconds")
print(f"6. Generalization (Train vs. Test Accuracy): {train_accuracy:.2f}% vs. {accuracy:.2f}%")
print(f"7. Model Calibration (AUC-ROC as Proxy): {auc_roc:.2f}")
print(f"8. Accuracy with Noise (Percentage of Correct Predictions): {accuracy_with_noise_percent:.2f}%")
print(f"9. Model Complexity: Suitable for SBLR; BNN would handle higher complexity better.")
print(f"10. AUC-ROC: {auc_roc:.2f}")
print(f"11. Confidence Intervals: Not available for SBLR.")
print(f"12. Scalability (Training Time): {training_time:.2f} seconds")
# Out:
# Batch 1/560 processed
# Batch 2/560 processed
# Batch 3/560 processed
# Batch 4/560 processed
# Batch 5/560 processed
# Batch 6/560 processed
# Batch 7/560 processed
# Batch 8/560 processed
# Batch 9/560 processed
# Batch 10/560 processed
# Batch 11/560 processed
# Batch 12/560 processed
# Batch 13/560 processed
# Batch 14/560 processed
# Batch 15/560 processed
# Batch 16/560 processed
# Batch 17/560 processed
# Batch 18/560 processed
# Batch 19/560 processed
# Batch 20/560 processed
# Batch 21/560 processed
# Batch 22/560 processed
# Batch 23/560 processed
# Batch 24/560 processed
# Batch 25/560 processed
# Batch 26/560 processed
# Batch 27/560 processed
# Batch 28/560 processed
# Batch 29/560 processed
# Batch 30/560 processed
# Batch 31/560 processed
# Batch 32/560 processed
# Batch 33/560 processed
# Batch 34/560 processed
# Batch 35/560 processed
# Batch 36/560 processed
# Batch 37/560 processed
# Batch 38/560 processed
# Batch 39/560 processed
# Batch 40/560 processed
# Batch 41/560 processed
# Batch 42/560 processed
# Batch 43/560 processed
# Batch 44/560 processed
# Batch 45/560 processed
# Batch 46/560 processed
# Batch 47/560 processed
# Batch 48/560 processed
# Batch 49/560 processed
# Batch 50/560 processed
# Batch 51/560 processed
# Batch 52/560 processed
# Batch 53/560 processed
# Batch 54/560 processed
# Batch 55/560 processed
# Batch 56/560 processed
# Batch 57/560 processed
# Batch 58/560 processed
# Batch 59/560 processed
# Batch 60/560 processed
# Batch 61/560 processed
# Batch 62/560 processed
# Batch 63/560 processed
# Batch 64/560 processed
# Batch 65/560 processed
# Batch 66/560 processed
# Batch 67/560 processed
# Batch 68/560 processed
# Batch 69/560 processed
# Batch 70/560 processed
# Batch 71/560 processed
# Batch 72/560 processed
# Batch 73/560 processed
# Batch 74/560 processed
# Batch 75/560 processed
# Batch 76/560 processed
# Batch 77/560 processed
# Batch 78/560 processed
# Batch 79/560 processed
# Batch 80/560 processed
# Batch 81/560 processed
# Batch 82/560 processed
# Batch 83/560 processed
# Batch 84/560 processed
# Batch 85/560 processed
# Batch 86/560 processed
# Batch 87/560 processed
# Batch 88/560 processed
# Batch 89/560 processed
# Batch 90/560 processed
# Batch 91/560 processed
# Batch 92/560 processed
# Batch 93/560 processed
# Batch 94/560 processed
# Batch 95/560 processed
# Batch 96/560 processed
# Batch 97/560 processed
# Batch 98/560 processed
# Batch 99/560 processed
# Batch 100/560 processed
# Batch 101/560 processed
# Batch 102/560 processed
# Batch 103/560 processed
# Batch 104/560 processed
# Batch 105/560 processed
# Batch 106/560 processed
# Batch 107/560 processed
# Batch 108/560 processed
# Batch 109/560 processed
# Batch 110/560 processed
# Batch 111/560 processed
# Batch 112/560 processed
# Batch 113/560 processed
# Batch 114/560 processed
# Batch 115/560 processed
# Batch 116/560 processed
# Batch 117/560 processed
# Batch 118/560 processed
# Batch 119/560 processed
# Batch 120/560 processed
# Batch 121/560 processed
# Batch 122/560 processed
# Batch 123/560 processed
# Batch 124/560 processed
# Batch 125/560 processed
# Batch 126/560 processed
# Batch 127/560 processed
# Batch 128/560 processed
# Batch 129/560 processed
# Batch 130/560 processed
# Batch 131/560 processed
# Batch 132/560 processed
# Batch 133/560 processed
# Batch 134/560 processed
# Batch 135/560 processed
# Batch 136/560 processed
# Batch 137/560 processed
# Batch 138/560 processed
# Batch 139/560 processed
# Batch 140/560 processed
# Batch 141/560 processed
# Batch 142/560 processed
# Batch 143/560 processed
# Batch 144/560 processed
# Batch 145/560 processed
# Batch 146/560 processed
# Batch 147/560 processed
# Batch 148/560 processed
# Batch 149/560 processed
# Batch 150/560 processed
# Batch 151/560 processed
# Batch 152/560 processed
# Batch 153/560 processed
# Batch 154/560 processed
# Batch 155/560 processed
# Batch 156/560 processed
# Batch 157/560 processed
# Batch 158/560 processed
# Batch 159/560 processed
# Batch 160/560 processed
# Batch 161/560 processed
# Batch 162/560 processed
# Batch 163/560 processed
# Batch 164/560 processed
# Batch 165/560 processed
# Batch 166/560 processed
# Batch 167/560 processed
# Batch 168/560 processed
# Batch 169/560 processed
# Batch 170/560 processed
# Batch 171/560 processed
# Batch 172/560 processed
# Batch 173/560 processed
# Batch 174/560 processed
# Batch 175/560 processed
# Batch 176/560 processed
# Batch 177/560 processed
# Batch 178/560 processed
# Batch 179/560 processed
# Batch 180/560 processed
# Batch 181/560 processed
# Batch 182/560 processed
# Batch 183/560 processed
# Batch 184/560 processed
# Batch 185/560 processed
# Batch 186/560 processed
# Batch 187/560 processed
# Batch 188/560 processed
# Batch 189/560 processed
# Batch 190/560 processed
# Batch 191/560 processed
# Batch 192/560 processed
# Batch 193/560 processed
# Batch 194/560 processed
# Batch 195/560 processed
# Batch 196/560 processed
# Batch 197/560 processed
# Batch 198/560 processed
# Batch 199/560 processed
# Batch 200/560 processed
# Batch 201/560 processed
# Batch 202/560 processed
# Batch 203/560 processed
# Batch 204/560 processed
# Batch 205/560 processed
# Batch 206/560 processed
# Batch 207/560 processed
# Batch 208/560 processed
# Batch 209/560 processed
# Batch 210/560 processed
# Batch 211/560 processed
# Batch 212/560 processed
# Batch 213/560 processed
# Batch 214/560 processed
# Batch 215/560 processed
# Batch 216/560 processed
# Batch 217/560 processed
# Batch 218/560 processed
# Batch 219/560 processed
# Batch 220/560 processed
# Batch 221/560 processed
# Batch 222/560 processed
# Batch 223/560 processed
# Batch 224/560 processed
# Batch 225/560 processed
# Batch 226/560 processed
# Batch 227/560 processed
# Batch 228/560 processed
# Batch 229/560 processed
# Batch 230/560 processed
# Batch 231/560 processed
# Batch 232/560 processed
# Batch 233/560 processed
# Batch 234/560 processed
# Batch 235/560 processed
# Batch 236/560 processed
# Batch 237/560 processed
# Batch 238/560 processed
# Batch 239/560 processed
# Batch 240/560 processed
# Batch 241/560 processed
# Batch 242/560 processed
# Batch 243/560 processed
# Batch 244/560 processed
# Batch 245/560 processed
# Batch 246/560 processed
# Batch 247/560 processed
# Batch 248/560 processed
# Batch 249/560 processed
# Batch 250/560 processed
# Batch 251/560 processed
# Batch 252/560 processed
# Batch 253/560 processed
# Batch 254/560 processed
# Batch 255/560 processed
# Batch 256/560 processed
# Batch 257/560 processed
# Batch 258/560 processed
# Batch 259/560 processed
# Batch 260/560 processed
# Batch 261/560 processed
# Batch 262/560 processed
# Batch 263/560 processed
# Batch 264/560 processed
# Batch 265/560 processed
# Batch 266/560 processed
# Batch 267/560 processed
# Batch 268/560 processed
# Batch 269/560 processed
# Batch 270/560 processed
# Batch 271/560 processed
# Batch 272/560 processed
# Batch 273/560 processed
# Batch 274/560 processed
# Batch 275/560 processed
# Batch 276/560 processed
# Batch 277/560 processed
# Batch 278/560 processed
# Batch 279/560 processed
# Batch 280/560 processed
# Batch 281/560 processed
# Batch 282/560 processed
# Batch 283/560 processed
# Batch 284/560 processed
# Batch 285/560 processed
# Batch 286/560 processed
# Batch 287/560 processed
# Batch 288/560 processed
# Batch 289/560 processed
# Batch 290/560 processed
# Batch 291/560 processed
# Batch 292/560 processed
# Batch 293/560 processed
# Batch 294/560 processed
# Batch 295/560 processed
# Batch 296/560 processed
# Batch 297/560 processed
# Batch 298/560 processed
# Batch 299/560 processed
# Batch 300/560 processed
# Batch 301/560 processed
# Batch 302/560 processed
# Batch 303/560 processed
# Batch 304/560 processed
# Batch 305/560 processed
# Batch 306/560 processed
# Batch 307/560 processed
# Batch 308/560 processed
# Batch 309/560 processed
# Batch 310/560 processed
# Batch 311/560 processed
# Batch 312/560 processed
# Batch 313/560 processed
# Batch 314/560 processed
# Batch 315/560 processed
# Batch 316/560 processed
# Batch 317/560 processed
# Batch 318/560 processed
# Batch 319/560 processed
# Batch 320/560 processed
# Batch 321/560 processed
# Batch 322/560 processed
# Batch 323/560 processed
# Batch 324/560 processed
# Batch 325/560 processed
# Batch 326/560 processed
# Batch 327/560 processed
# Batch 328/560 processed
# Batch 329/560 processed
# Batch 330/560 processed
# Batch 331/560 processed
# Batch 332/560 processed
# Batch 333/560 processed
# Batch 334/560 processed
# Batch 335/560 processed
# Batch 336/560 processed
# Batch 337/560 processed
# Batch 338/560 processed
# Batch 339/560 processed
# Batch 340/560 processed
# Batch 341/560 processed
# Batch 342/560 processed
# Batch 343/560 processed
# Batch 344/560 processed
# Batch 345/560 processed
# Batch 346/560 processed
# Batch 347/560 processed
# Batch 348/560 processed
# Batch 349/560 processed
# Batch 350/560 processed
# Batch 351/560 processed
# Batch 352/560 processed
# Batch 353/560 processed
# Batch 354/560 processed
# Batch 355/560 processed
# Batch 356/560 processed
# Batch 357/560 processed
# Batch 358/560 processed
# Batch 359/560 processed
# Batch 360/560 processed
# Batch 361/560 processed
# Batch 362/560 processed
# Batch 363/560 processed
# Batch 364/560 processed
# Batch 365/560 processed
# Batch 366/560 processed
# Batch 367/560 processed
# Batch 368/560 processed
# Batch 369/560 processed
# Batch 370/560 processed
# Batch 371/560 processed
# Batch 372/560 processed
# Batch 373/560 processed
# Batch 374/560 processed
# Batch 375/560 processed
# Batch 376/560 processed
# Batch 377/560 processed
# Batch 378/560 processed
# Batch 379/560 processed
# Batch 380/560 processed
# Batch 381/560 processed
# Batch 382/560 processed
# Batch 383/560 processed
# Batch 384/560 processed
# Batch 385/560 processed
# Batch 386/560 processed
# Batch 387/560 processed
# Batch 388/560 processed
# Batch 389/560 processed
# Batch 390/560 processed
# Batch 391/560 processed
# Batch 392/560 processed
# Batch 393/560 processed
# Batch 394/560 processed
# Batch 395/560 processed
# Batch 396/560 processed
# Batch 397/560 processed
# Batch 398/560 processed
# Batch 399/560 processed
# Batch 400/560 processed
# Batch 401/560 processed
# Batch 402/560 processed
# Batch 403/560 processed
# Batch 404/560 processed
# Batch 405/560 processed
# Batch 406/560 processed
# Batch 407/560 processed
# Batch 408/560 processed
# Batch 409/560 processed
# Batch 410/560 processed
# Batch 411/560 processed
# Batch 412/560 processed
# Batch 413/560 processed
# Batch 414/560 processed
# Batch 415/560 processed
# Batch 416/560 processed
# Batch 417/560 processed
# Batch 418/560 processed
# Batch 419/560 processed
# Batch 420/560 processed
# Batch 421/560 processed
# Batch 422/560 processed
# Batch 423/560 processed
# Batch 424/560 processed
# Batch 425/560 processed
# Batch 426/560 processed
# Batch 427/560 processed
# Batch 428/560 processed
# Batch 429/560 processed
# Batch 430/560 processed
# Batch 431/560 processed
# Batch 432/560 processed
# Batch 433/560 processed
# Batch 434/560 processed
# Batch 435/560 processed
# Batch 436/560 processed
# Batch 437/560 processed
# Batch 438/560 processed
# Batch 439/560 processed
# Batch 440/560 processed
# Batch 441/560 processed
# Batch 442/560 processed
# Batch 443/560 processed
# Batch 444/560 processed
# Batch 445/560 processed
# Batch 446/560 processed
# Batch 447/560 processed
# Batch 448/560 processed
# Batch 449/560 processed
# Batch 450/560 processed
# Batch 451/560 processed
# Batch 452/560 processed
# Batch 453/560 processed
# Batch 454/560 processed
# Batch 455/560 processed
# Batch 456/560 processed
# Batch 457/560 processed
# Batch 458/560 processed
# Batch 459/560 processed
# Batch 460/560 processed
# Batch 461/560 processed
# Batch 462/560 processed
# Batch 463/560 processed
# Batch 464/560 processed
# Batch 465/560 processed
# Batch 466/560 processed
# Batch 467/560 processed
# Batch 468/560 processed
# Batch 469/560 processed
# Batch 470/560 processed
# Batch 471/560 processed
# Batch 472/560 processed
# Batch 473/560 processed
# Batch 474/560 processed
# Batch 475/560 processed
# Batch 476/560 processed
# Batch 477/560 processed
# Batch 478/560 processed
# Batch 479/560 processed
# Batch 480/560 processed
# Batch 481/560 processed
# Batch 482/560 processed
# Batch 483/560 processed
# Batch 484/560 processed
# Batch 485/560 processed
# Batch 486/560 processed
# Batch 487/560 processed
# Batch 488/560 processed
# Batch 489/560 processed
# Batch 490/560 processed
# Batch 491/560 processed
# Batch 492/560 processed
# Batch 493/560 processed
# Batch 494/560 processed
# Batch 495/560 processed
# Batch 496/560 processed
# Batch 497/560 processed
# Batch 498/560 processed
# Batch 499/560 processed
# Batch 500/560 processed
# Batch 501/560 processed
# Batch 502/560 processed
# Batch 503/560 processed
# Batch 504/560 processed
# Batch 505/560 processed
# Batch 506/560 processed
# Batch 507/560 processed
# Batch 508/560 processed
# Batch 509/560 processed
# Batch 510/560 processed
# Batch 511/560 processed
# Batch 512/560 processed
# Batch 513/560 processed
# Batch 514/560 processed
# Batch 515/560 processed
# Batch 516/560 processed
# Batch 517/560 processed
# Batch 518/560 processed
# Batch 519/560 processed
# Batch 520/560 processed
# Batch 521/560 processed
# Batch 522/560 processed
# Batch 523/560 processed
# Batch 524/560 processed
# Batch 525/560 processed
# Batch 526/560 processed
# Batch 527/560 processed
# Batch 528/560 processed
# Batch 529/560 processed
# Batch 530/560 processed
# Batch 531/560 processed
# Batch 532/560 processed
# Batch 533/560 processed
# Batch 534/560 processed
# Batch 535/560 processed
# Batch 536/560 processed
# Batch 537/560 processed
# Batch 538/560 processed
# Batch 539/560 processed
# Batch 540/560 processed
# Batch 541/560 processed
# Batch 542/560 processed
# Batch 543/560 processed
# Batch 544/560 processed
# Batch 545/560 processed
# Batch 546/560 processed
# Batch 547/560 processed
# Batch 548/560 processed
# Batch 549/560 processed
# Batch 550/560 processed
# Batch 551/560 processed
# Batch 552/560 processed
# Batch 553/560 processed
# Batch 554/560 processed
# Batch 555/560 processed
# Batch 556/560 processed
# Batch 557/560 processed
# Batch 558/560 processed
# Batch 559/560 processed
# Batch 560/560 processed
#
# Training Time: 219.44 seconds
# Accuracy: 83.13%
# Log-Loss: 0.53
# Precision: 0.83
# Recall: 0.83
# F1-Score: 0.83
# Prediction Variance (proxy for uncertainty): 0.0996
# Training Time: 219.44 seconds
# Training Accuracy: 83.24%
# Test Accuracy (for Generalization check): 83.13%
# Generalization Check: No significant drop indicates good generalization
# AUC-ROC (Calibration Proxy): 0.90
# Accuracy with Noise (Percentage of Correct Predictions): 83.13%
# Model Complexity: SBLR is simpler than BNN, suited for smaller data with fewer parameters.
# AUC-ROC: 0.90
# Scalability Check (Training Time for Large Datasets): 219.44 seconds
#
# === Model Evaluation Summary ===
# 1. Accuracy: 83.13%
# 2. Log-Loss: 0.53
# 3. Precision: 0.83, Recall: 0.83, F1-Score: 0.83
# 4. Uncertainty Estimation (Variance): 0.0996
# 5. Training Time: 219.44 seconds
# 6. Generalization (Train vs. Test Accuracy): 83.24% vs. 83.13%
# 7. Model Calibration (AUC-ROC as Proxy): 0.90
# 8. Accuracy with Noise (Percentage of Correct Predictions): 83.13%
# 9. Model Complexity: Suitable for SBLR; BNN would handle higher complexity better.
# 10. AUC-ROC: 0.90
# 11. Confidence Intervals: Not available for SBLR.
# 12. Scalability (Training Time): 219.44 seconds

# %%
import tensorflow_datasets as tfds
import pandas as pd

# Load Yelp Dataset
(train_data, _), _ = tfds.load('yelp_polarity_reviews', split=['train', 'test'], with_info=True, as_supervised=True)

# Convert the data to a Pandas DataFrame
def extract_data(dataset):
    texts = []
    labels = []
    for text, label in tfds.as_numpy(dataset):
        texts.append(text.decode('utf-8'))
        labels.append(int(label))
    return texts, labels

train_texts, train_labels = extract_data(train_data)
train_df = pd.DataFrame({
    'text': train_texts,
    'label': train_labels
})

# Save DataFrame to CSV
train_csv_path = '/mnt/data/yelp_train_data.csv'  # Adjust this path as needed
train_df.to_csv(train_csv_path, index=False)
print("Dataset saved to", train_csv_path)
# Out:
# Downloading and preparing dataset 158.67 MiB (download: 158.67 MiB, generated: 435.14 MiB, total: 593.80 MiB) to /root/tensorflow_datasets/yelp_polarity_reviews/0.2.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/560000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/yelp_polarity_reviews/incomplete.HYYFGZ_0.2.0/yelp_polarity_reviews-train.…
# Generating test examples...:   0%|          | 0/38000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/yelp_polarity_reviews/incomplete.HYYFGZ_0.2.0/yelp_polarity_reviews-test.t…
# Dataset yelp_polarity_reviews downloaded and prepared to /root/tensorflow_datasets/yelp_polarity_reviews/0.2.0. Subsequent calls will reuse this data.

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
import numpy as np

# Assuming the yelp dataset is used as per the earlier setup:
# Calculate FPR, TPR, and thresholds for the ROC curve based on validation predictions
fpr, tpr, thresholds = roc_curve(y_validation, validation_pred_prob)
roc_auc = auc(fpr, tpr)

# Plot ROC Curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')  # Diagonal line for random guessing
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# Print AUC-ROC for reference
print(f"AUC-ROC: {roc_auc:.2f}")
# Out:
# AUC-ROC: 0.90

# %%
from sklearn.preprocessing import MinMaxScaler

# Scale predictions to [0, 1] using MinMaxScaler
scaler = MinMaxScaler()
y_pred_prob_scaled = scaler.fit_transform(y_pred_prob.reshape(-1, 1)).flatten()

# Compute calibration curve
prob_true, prob_pred = calibration_curve(y_test, y_pred_prob_scaled, n_bins=10, strategy='uniform')

# Plot Calibration Curve
plt.figure(figsize=(8, 6))
plt.plot(prob_pred, prob_true, marker='o', color='darkorange', label='Model Calibration')
plt.plot([0, 1], [0, 1], linestyle='--', color='navy', label='Perfectly Calibrated')
plt.xlabel('Predicted Probability')
plt.ylabel('True Probability')
plt.title('Calibration Curve (Reliability Plot)')
plt.legend(loc="best")
plt.show()

# %%
# Required Libraries
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.linear_model import BayesianRidge
from sklearn.metrics import accuracy_score
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Load the Yelp Dataset from CSV
train_df = pd.read_csv('yelp_train_data.csv')
validation_df = pd.read_csv('yelp_test_data.csv')

# Step 2: Combine for consistent vectorization
df = pd.concat([train_df, validation_df], ignore_index=True)

# Step 3: Text Vectorization
vectorizer = CountVectorizer(stop_words='english')
X = vectorizer.fit_transform(df['text'])

# Step 4: Dimensionality Reduction
svd = TruncatedSVD(n_components=500, random_state=42)
X_reduced = svd.fit_transform(X)

# Step 5: Separate the training and validation data after vectorization and dimensionality reduction
X_train, X_validation = X_reduced[:len(train_df)], X_reduced[len(train_df):]
y_train, y_validation = train_df['label'], validation_df['label']

# Step 6: Define and Train the Model
model = BayesianRidge()
batch_size = 1000
n_batches = int(np.ceil(X_train.shape[0] / batch_size))

for batch_num in range(n_batches):
    start_idx = batch_num * batch_size
    end_idx = min((batch_num + 1) * batch_size, X_train.shape[0])
    X_batch = X_train[start_idx:end_idx]
    y_batch = y_train[start_idx:end_idx]
    model.fit(X_batch, y_batch)

# Step 7: Calculate Train and Validation Accuracies
train_pred_prob = model.predict(X_train)
train_pred_class = [1 if prob > 0.5 else 0 for prob in train_pred_prob]
train_accuracy = accuracy_score(y_train, train_pred_class) * 100

validation_pred_prob = model.predict(X_validation)
validation_pred_class = [1 if prob > 0.5 else 0 for prob in validation_pred_prob]
validation_accuracy = accuracy_score(y_validation, validation_pred_class) * 100

# Step 8: Plot Generalization (Train vs. Validation Accuracy)
plt.figure(figsize=(8, 5))
plt.bar(['Train Accuracy', 'Validation Accuracy'], [train_accuracy, validation_accuracy], color=['skyblue', 'salmon'])
plt.ylim(0, 100)
plt.ylabel('Accuracy (%)')
plt.title('Generalization: Train vs. Validation Accuracy')
plt.text(0, train_accuracy + 2, f'{train_accuracy:.2f}%', ha='center')
plt.text(1, validation_accuracy + 2, f'{validation_accuracy:.2f}%', ha='center')
plt.show()
